# %%
import numpy as np
import pandas as pd

# %%
path = '/mnt/c/users/Isaac/onedrive/desktop/gpgn268/coursework-peck/ds01-well-log/data/well-log-data/372-U1517A_res-phase-nscope.csv'
df = pd.read_csv(path, skiprows=[0,1,2,3,5])

# %%
df.head()
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1226 entries, 0 to 1225
# Data columns (total 16 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   DEPTH_LSF  1226 non-null   float64
#  1   P16B       1226 non-null   float64
#  2   P16H       1226 non-null   float64
#  3   P16L       1226 non-null   float64
#  4   P22B       1226 non-null   float64
#  5   P22H       1226 non-null   float64
#  6   P22L       1226 non-null   float64
#  7   P28B       1226 non-null   float64
#  8   P28H       1226 non-null   float64
#  9   P28L       1226 non-null   float64
#  10  P34B       1226 non-null   float64
#  11  P34H       1226 non-null   float64
#  12  P34L       1226 non-null   float64
#  13  P40B       1226 non-null   float64
#  14  P40H       1226 non-null   float64
#  15  P40L       1226 non-null   float64
# dtypes: float64(16)
# memory usage: 153.4 KB

# %%
df.columns
# Out:
# Index(['DEPTH_LSF', 'P16B', 'P16H', 'P16L', 'P22B', 'P22H', 'P22L', 'P28B',
#        'P28H', 'P28L', 'P34B', 'P34H', 'P34L', 'P40B', 'P40H', 'P40L'],
#       dtype='str')

# %%
df.T
# Out:
#                0         1         2         3         4         5     \
# DEPTH_LSF  0.134800  0.287200  0.439600  0.592000  0.744400  0.896800
# P16B       0.609138  0.627580  0.644199  0.663892  0.682845  0.731617
# P16H       0.606420  0.606823  0.610627  0.619708  0.630840  0.694116
# P16L       0.609138  0.627579  0.644199  0.663892  0.682845  0.731617
# P22B       0.625390  0.646545  0.663118  0.681017  0.697899  0.745441
# P22H       0.628182  0.632340  0.632921  0.637017  0.645322  0.712391
# P22L       0.625390  0.646545  0.663118  0.681017  0.697899  0.745441
# P28B       0.633311  0.654598  0.674138  0.693011  0.709838  0.756381
# P28H       0.642043  0.649771  0.650050  0.653297  0.659337  0.728494
# P28L       0.633311  0.654598  0.674138  0.693011  0.709838  0.756381
# P34B       0.635440  0.654733  0.678495  0.699174  0.717195  0.762395
# P34H       0.646374  0.655505  0.658393  0.662530  0.668764  0.740624
# ...

# %%
df.describe()
# Out:
#          DEPTH_LSF         P16B         P16H         P16L         P22B  \
# count  1226.000000  1226.000000  1226.000000  1226.000000  1226.000000
# mean     93.479800     1.341873     1.303217     1.356043     1.373337
# std      53.958748     0.223072     0.258176     0.224783     0.213214
# min       0.134800     0.249499     0.229939     0.249499     0.264302
# 25%      46.807300     1.271618     1.240749     1.285699     1.297918
# 50%      93.479800     1.340664     1.319333     1.357524     1.363818
# 75%     140.152300     1.461021     1.444107     1.475915     1.489279
# max     186.824800     2.068212     2.068210     2.018047     2.099740
#
#               P22H         P22L         P28B         P28H         P28L  \
# count  1226.000000  1226.000000  1226.000000  1226.000000  1226.000000
# mean      1.339729     1.387603     1.400060     1.371811     1.413030
# std       0.245582     0.213473     0.206943     0.236748     0.205067
# ...

# %%
df.set_index("DEPTH_LSF", inplace=True)

# %%
df.loc[0.2872:0.7444, "P16L":"P288"].max()
# Out:
# P16L    0.682845
# P22B    0.697899
# P22H    0.645322
# P22L    0.697899
# dtype: float64

# %%
subset = df.loc[0.2872:0.7444, "P16L":"P288"]

# %%
subset.describe()
# Out:
#            P16L      P22B      P22H      P22L
# count  4.000000  4.000000  4.000000  4.000000
# mean   0.654629  0.672145  0.636900  0.672145
# std    0.023961  0.022202  0.005988  0.022202
# min    0.627579  0.646545  0.632340  0.646545
# 25%    0.640044  0.658975  0.632775  0.658975
# 50%    0.654046  0.672067  0.634969  0.672067
# 75%    0.668630  0.685237  0.639093  0.685237
# max    0.682845  0.697899  0.645322  0.697899

# %%
df.plot()
# Out:
# <Axes: xlabel='DEPTH_LSF'>

# %%
band_facts = {"name": "Coldplay", "studio albunms":9}
major_facts = dict(name="Geophysics",tracks=6)

# %%
print(type(band_facts))
print(type(major_facts))
print(band_facts)
print(major_facts)
# Out:
# <class 'dict'>
# <class 'dict'>
# {'name': 'Coldplay', 'studio albunms': 9}
# {'name': 'Geophysics', 'tracks': 6}

# %%
band_facts["name"]
# Out:
# 'Coldplay'

# %%
band_facts["grammys"] = 7
print(band_facts)
